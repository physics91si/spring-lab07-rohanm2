# %% [markdown]
# # Lab 07

# %%
from skimage import data, io
import numpy as np
from matplotlib import pyplot as plt
import time

# %% [markdown]
# Part 1

# %%
# Load image here. Display the image and the image shape.

image = "starry.jpg"
io.imshow(image)
plt.show()

print(type(image)) 
print(image.shape)

#cat = data.chelsea()
#print(type(cat))
#print(cat.shape)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-bb46f888aed7> in <module>
#       6
#       7 print(type(image))
# ----> 8 print(image.shape)
#       9
#      10 #cat = data.chelsea()
#
# AttributeError: 'str' object has no attribute 'shape'

# %%
# Make the color arrays and display them on a labelled subplot.

# %% [markdown]
# ## Part 2

# %%
from math import sqrt
from skimage.feature import blob_log, blob_doh
from skimage.color import rgb2gray

# %%
# Here is the image of the Hubble Deep Field. 
image = data.hubble_deep_field()[0:500, 0:500]
io.imshow(image)
plt.show()

grayscale = rgb2gray(image)
io.imshow(grayscale, cmap=plt.cm.gray)
plt.show()
#Convert the image to grayscale and display next to the original.

# %%
# Apply the two Blob detection methods and measure the time taken by the algorithms.

A = blob_log(image, max_sigma = 30, num_sigma = 10, threshold = .4)
print(A)

# %%
# Plot the 2 methods side-by-side along with circle patches.
